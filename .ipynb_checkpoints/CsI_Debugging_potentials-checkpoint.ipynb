# %%
from pbcpy.grid import Plot
from pbcpy.formats.qepp import PP
from pbcpy.formats.xsf import XSF
from pbcpy.base import Coord
from pbcpy.base import Cell
from pbcpy.base import Cell
from pbcpy.grid import Grid
import numpy as np
from pbcpy.base import pbcarray
from matplotlib.ticker import OldScalarFormatter, ScalarFormatter
import  matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# #### Crystal reference

# %%
map_2 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI2_map.pp').read()
map_2_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI2_map_charged.pp').read()

# %%
map_16 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI16_map.pp').read()
map_16_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI16_map_charged.pp').read()

# %%
map_54 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI54_map.pp').read()
map_54_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI54_map_charged.pp').read()

# %%
map_128 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI128_map.pp').read()
map_128_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Crystal_ref/CsI128_map_charged.pp').read()

# %%
mpl.rcParams['figure.figsize'] = (20,20)
distance_scalar = 40

x0 = map_2.ions[0].pos
x1 = map_16.ions[0].pos
x2 = map_54.ions[0].pos
x3 = map_128.ions[0].pos

r0 = distance_scalar*Coord(pos=[1.0,0.0,0.0], cell=map_2.cell)
r1 = distance_scalar*Coord(pos=[1.0,0.0,0.0], cell=map_16.cell)
r2 = distance_scalar*Coord(pos=[1.0,0.0,0.0], cell=map_54.cell)
r3 = distance_scalar*Coord(pos=[1.0,0.0,0.0], cell=map_128.cell)

print(x1, 'label0', map_2.ions[0].label)
print(x2, 'label1', map_16.ions[0].label)
print(x1, 'label2', map_54.ions[0].label)
print(x2, 'label3', map_128.ions[0].label)

gridpoints = 4000
d0 = (r0).length()*0.52918
d1 = (r1).length()*0.52918
d2 = (r2).length()*0.52918
d3 = (r3).length()*0.52918

scalar0 = d0/gridpoints
scalar1 = d1/gridpoints
scalar2 = d2/gridpoints
scalar3 = d3/gridpoints

xvalues = np.arange(0,gridpoints,1)

fig, axes = plt.subplots(nrows=2, ncols=2)

plotcut_1D_map_2 = map_2.plot.get_plotcut(x0=x0,r0=r0, nr=gridpoints)
plotcut_1D_map_16 = map_16.plot.get_plotcut(x0=x1,r0=r1, nr=gridpoints)
plotcut_1D_map_54 = map_54.plot.get_plotcut(x0=x2,r0=r2, nr=gridpoints)
plotcut_1D_map_128 = map_128.plot.get_plotcut(x0=x3,r0=r3, nr=gridpoints)
plotcut_1D_map_2_charged = map_2_charged.plot.get_plotcut(x0=x0,r0=r0, nr=gridpoints)
plotcut_1D_map_16_charged = map_16_charged.plot.get_plotcut(x0=x1,r0=r1, nr=gridpoints)
plotcut_1D_map_54_charged = map_54_charged.plot.get_plotcut(x0=x2,r0=r2, nr=gridpoints)
plotcut_1D_map_128_charged = map_128_charged.plot.get_plotcut(x0=x3,r0=r3, nr=gridpoints)

axes[0][0].plot(xvalues*scalar0, plotcut_1D_map_2.values, label = '2')
axes[0][1].plot(xvalues*scalar1, plotcut_1D_map_16.values, label = '16')
axes[1][0].plot(xvalues*scalar2, plotcut_1D_map_54.values, label = '54')
axes[1][1].plot(xvalues*scalar3, plotcut_1D_map_128.values, label = '128')

axes[0][0].plot(xvalues*scalar0, plotcut_1D_map_2_charged.values, label = '2 charged')
axes[0][1].plot(xvalues*scalar1, plotcut_1D_map_16_charged.values, label = '16 charged')
axes[1][0].plot(xvalues*scalar2, plotcut_1D_map_54_charged.values, label = '54 charged')
axes[1][1].plot(xvalues*scalar3, plotcut_1D_map_128_charged.values, label = '128 charged')

axes[0][0].set_xlabel(' d/ Å')
axes[0][1].set_xlabel(' d/ Å')
axes[1][0].set_xlabel(' d/ Å')
axes[1][1].set_xlabel(' d/ Å')

axes[0][0].set_ylabel(' d/ Å')
axes[0][1].set_ylabel(' d/ Å')
axes[1][0].set_ylabel(' d/ Å')
axes[1][1].set_ylabel(' d/ Å')

axes[0][0].legend()
axes[0][1].legend()
axes[1][0].legend()
axes[1][1].legend()

plt.show()
# Out:
# [ 4.31518963  4.31518963  4.31518963] label0 I
# [ 4.31518963  4.31518963  4.31518963] label1 I
# [ 4.31518963  4.31518963  4.31518963] label2 I
# [ 4.31518963  4.31518963  4.31518963] label3 I

# %%
map_2 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI2_map.pp').read()
map_2_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI2_map_charged.pp').read()

# %%
map_16 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI16_map.pp').read()
map_16_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI16_map_charged.pp').read()

# %%
map_54 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI54_map.pp').read()
map_54_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI54_map_charged.pp').read()

# %%
map_128 = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI128_map.pp').read()
map_128_charged = PP('/home/johannes/Documents/nm3/Test_System/Cs_I_FINAL/emb_pot/Vacuum_ref/CsI128_map_charged.pp').read()

# %%
mpl.rcParams['figure.figsize'] = (20,20)
distance_scalar = 40

x0 = map_2.ions[0].pos
x1 = map_16.ions[0].pos
x2 = map_54.ions[0].pos
x3 = map_128.ions[0].pos

r0 = distance_scalar*Coord(pos=[1.0,1.0,1.0], cell=map_2.cell)
r1 = distance_scalar*Coord(pos=[1.0,1.0,1.0], cell=map_16.cell)
r2 = distance_scalar*Coord(pos=[1.0,1.0,1.0], cell=map_54.cell)
r3 = distance_scalar*Coord(pos=[1.0,1.0,1.0], cell=map_128.cell)

print(x1, 'label0', map_2.ions[0].label)
print(x2, 'label1', map_16.ions[0].label)
print(x1, 'label2', map_54.ions[0].label)
print(x2, 'label3', map_128.ions[0].label)

gridpoints = 4000
d0 = (r0).length()*0.52918
d1 = (r1).length()*0.52918
d2 = (r2).length()*0.52918
d3 = (r3).length()*0.52918

scalar0 = d0/gridpoints
scalar1 = d1/gridpoints
scalar2 = d2/gridpoints
scalar3 = d3/gridpoints

xvalues = np.arange(0,gridpoints,1)

fig, axes = plt.subplots(nrows=2, ncols=2)

plotcut_1D_map_2 = map_2.plot.get_plotcut(x0=x0,r0=r0, nr=gridpoints)
plotcut_1D_map_16 = map_16.plot.get_plotcut(x0=x1,r0=r1, nr=gridpoints)
plotcut_1D_map_54 = map_54.plot.get_plotcut(x0=x2,r0=r2, nr=gridpoints)
plotcut_1D_map_128 = map_128.plot.get_plotcut(x0=x3,r0=r3, nr=gridpoints)
plotcut_1D_map_2_charged = map_2_charged.plot.get_plotcut(x0=x0,r0=r0, nr=gridpoints)
plotcut_1D_map_16_charged = map_16_charged.plot.get_plotcut(x0=x1,r0=r1, nr=gridpoints)
plotcut_1D_map_54_charged = map_54_charged.plot.get_plotcut(x0=x2,r0=r2, nr=gridpoints)
plotcut_1D_map_128_charged = map_128_charged.plot.get_plotcut(x0=x3,r0=r3, nr=gridpoints)

axes[0][0].plot(xvalues*scalar0, plotcut_1D_map_2.values, label = '2')
axes[0][1].plot(xvalues*scalar1, plotcut_1D_map_16.values, label = '16')
axes[1][0].plot(xvalues*scalar2, plotcut_1D_map_54.values, label = '54')
axes[1][1].plot(xvalues*scalar3, plotcut_1D_map_128.values, label = '128')

axes[0][0].plot(xvalues*scalar0, plotcut_1D_map_2_charged.values, label = '2 charged')
axes[0][1].plot(xvalues*scalar1, plotcut_1D_map_16_charged.values, label = '16 charged')
axes[1][0].plot(xvalues*scalar2, plotcut_1D_map_54_charged.values, label = '54 charged')
axes[1][1].plot(xvalues*scalar3, plotcut_1D_map_128_charged.values, label = '128 charged')

axes[0][0].set_xlabel(' d/ Å')
axes[0][1].set_xlabel(' d/ Å')
axes[1][0].set_xlabel(' d/ Å')
axes[1][1].set_xlabel(' d/ Å')

axes[0][0].set_ylabel(' d/ Å')
axes[0][1].set_ylabel(' d/ Å')
axes[1][0].set_ylabel(' d/ Å')
axes[1][1].set_ylabel(' d/ Å')

axes[0][0].legend()
axes[0][1].legend()
axes[1][0].legend()
axes[1][1].legend()

plt.show()
# Out:
# [ 4.31518963  4.31518963  4.31518963] label0 I
# [ 4.31518963  4.31518963  4.31518963] label1 I
# [ 4.31518963  4.31518963  4.31518963] label2 I
# [ 4.31518963  4.31518963  4.31518963] label3 I
